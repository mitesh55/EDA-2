# %%
# !pip install ppscore
# Out:
# ...
#   Created wheel for ppscore: filename=ppscore-1.2.0-py2.py3-none-any.whl size=13055 sha256=57a260623264aa8bf6ba6b74cb2f58fb11d9c0df9aeb20399dd8815e71e1ee12
#   Stored in directory: c:\users\mites\appdata\local\pip\cache\wheels\fb\0e\65\da65ce669381fc01b6ef990d301d3586991f89bff1175877a4
# Successfully built ppscore
# ...

# %%
import ppscore as pps
import pandas as pd

# %%
data = pd.read_csv(r'IRIS.csv')
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# pps.score(data, 'sepal_length', 'petal_length')   # 0.55
# pps.score(data, 'petal_length', 'sepal_length')     # 0.5244
# Out:
# {'x': 'petal_length',
#  'y': 'sepal_length',
#  'ppscore': 0.5244796414849711,
#  'case': 'regression',
#  'is_valid_score': True,
#  'metric': 'mean absolute error',
#  'baseline_score': 0.6846666666666668,
#  'model_score': 0.32557293879662313,
#  'model': DecisionTreeRegressor()}

# %%
# pps_matrix :
pps.matrix(data)
# Out:
#                x             y   ppscore            case  is_valid_score  \
# 0   sepal_length  sepal_length  1.000000  predict_itself            True
# 1   sepal_length   sepal_width  0.000000      regression            True
# 2   sepal_length  petal_length  0.550575      regression            True
# 3   sepal_length   petal_width  0.431163      regression            True
# 4   sepal_length       species  0.471649  classification            True
# 5    sepal_width  sepal_length  0.001902      regression            True
# 6    sepal_width   sepal_width  1.000000  predict_itself            True
# 7    sepal_width  petal_length  0.167773      regression            True
# 8    sepal_width   petal_width  0.129681      regression            True
# 9    sepal_width       species  0.179145  classification            True
# 10  petal_length  sepal_length  0.524480      regression            True
# 11  petal_length   sepal_width  0.041298      regression            True
# ...
